# %% [markdown]
# _______________
# # nol

# %%
# %pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (1.13.0)
# Requirement already satisfied: altair>=3.2.0 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (4.2.0)
# Requirement already satisfied: watchdog in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (2.1.9)
# Requirement already satisfied: python-dateutil in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: protobuf!=3.20.2,<4,>=3.12 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (5.0.0)
# Requirement already satisfied: tornado>=5.0 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (6.2)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (1.5.0)
# Requirement already satisfied: cachetools>=4.0 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (3.1.27)
# Requirement already satisfied: toml in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: validators>=0.2 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (0.20.0)
# Requirement already satisfied: pympler>=0.9 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: semver in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (2.13.0)
# Requirement already satisfied: packaging>=14.1 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (21.3)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (4.3.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (0.8.0b3)
# Requirement already satisfied: requests>=2.4 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: click>=7.0 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (8.1.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (9.2.0)
# Requirement already satisfied: tzlocal>=1.1 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (4.2)
# Requirement already satisfied: rich>=10.11.0 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (12.6.0)
# Requirement already satisfied: blinker>=1.0.0 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (1.5)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from streamlit) (1.23.3)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from altair>=3.2.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from altair>=3.2.0->streamlit) (4.16.0)
# Requirement already satisfied: entrypoints in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from altair>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: toolz in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from altair>=3.2.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from click>=7.0->streamlit) (0.4.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from gitpython!=3.1.19->streamlit) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from packaging>=14.1->streamlit) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from pandas>=0.21.0->streamlit) (2022.4)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from requests>=2.4->streamlit) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from requests>=2.4->streamlit) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from requests>=2.4->streamlit) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from requests>=2.4->streamlit) (2022.9.24)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from rich>=10.11.0->streamlit) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from rich>=10.11.0->streamlit) (2.13.0)
# Requirement already satisfied: tzdata in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from tzlocal>=1.1->streamlit) (2022.4)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from tzlocal>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from validators>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\user\anaconda3\envs\meet_5\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns


df_hpmkb = pd.read_excel('D:\DQLAB_TETRIS_BATCH3_DATA_ANALYST\pangan\modern\harga-pasar-modern-komoditas-beras.xls')
df_hpmkb.head()
# Out:
#    No.        Provinsi 01/2020 02/2020  03/2020  04/2020  05/2020  06/2020  \
# 0    I  SEMUA PROVINSI   14400   14250    14150    14100    14000    14000
# 1   II            ACEH   12750   12750    12600    12500    12500    12500
# 2  III  SUMATERA UTARA   12600   12600    12550    12600    12550    12500
# 3   IV  SUMATERA BARAT   15400   15400    15400    15300    15400    15400
# 4    V            RIAU   12950   12950    13050    13050    13200    13050
#
#    07/2020  08/2020  ...  02/2022  03/2022  04/2022  05/2022  06/2022  \
# 0    14000    14000  ...    13850    13800    13800    13800    13750
# 1    12500    12500  ...    12500    12500    12400    12400    12400
# 2    12550    12550  ...    12850    12950    12950    12950    12950
# 3    15400    14600  ...    15550    15550    15700    15700    15700
# 4    13050    13050  ...    12400    12200    12600    12600    12600
#
#    07/2022  08/2022  09/2022  10/2022  11/2022
# 0    13750    13750    13800    13850        -
# 1    12400    12400    12500    12600        -
# 2    12950    12600    12600    12650        -
# 3    15800    15850    15850    16100        -
# 4    12600    12600    12650    12800        -
#
# [5 rows x 37 columns]

# %%
df_hpmkb.describe()
# Out:
#             03/2020       04/2020       05/2020       06/2020       07/2020  \
# count     35.000000     35.000000     35.000000     35.000000     35.000000
# mean   14102.857143  14307.142857  13940.000000  13944.285714  14281.428571
# std     2205.805937   2730.038323   2065.358536   2083.011516   2764.057272
# min    10900.000000  10400.000000  10400.000000  10000.000000  10000.000000
# 25%    12625.000000  12700.000000  12700.000000  12725.000000  12800.000000
# 50%    13150.000000  13200.000000  13200.000000  13250.000000  13300.000000
# 75%    15200.000000  15350.000000  14150.000000  14150.000000  14800.000000
# max    19750.000000  24650.000000  20050.000000  20050.000000  24750.000000
#
#             08/2020       09/2020       10/2020       11/2020       12/2020  \
# count     35.000000     35.000000     35.000000     35.000000     35.000000
# mean   13920.000000  13912.857143  13947.142857  13945.714286  13952.857143
# std     2096.081779   2066.338864   2066.751602   2045.309247   2068.494155
# min    10000.000000  10000.000000  10000.000000  10100.000000  10100.000000
# 25%    12625.000000  12625.000000  12725.000000  12800.000000  12800.000000
# 50%    13200.000000  13250.000000  13250.000000  13250.000000  13250.000000
# 75%    14225.000000  14275.000000  14275.000000  14275.000000  14275.000000
# max    20150.000000  19850.000000  19850.000000  19850.000000  20050.000000
#
#        ...       01/2022       02/2022       03/2022       04/2022  \
# count  ...     35.000000     35.000000     35.000000     35.000000
# mean   ...  13824.285714  13861.428571  13858.571429  13770.000000
# std    ...   2495.241690   2482.766653   2484.022050   2390.274412
# min    ...  10450.000000  10450.000000  10450.000000  10500.000000
# 25%    ...  12800.000000  12825.000000  12875.000000  12875.000000
# 50%    ...  13100.000000  13100.000000  13100.000000  13100.000000
# 75%    ...  13925.000000  13875.000000  13875.000000  13850.000000
# max    ...  24900.000000  24850.000000  24850.000000  24850.000000
#
#             05/2022       06/2022       07/2022       08/2022       09/2022  \
# count     35.000000     35.000000     35.000000     35.000000     35.000000
# mean   13784.285714  13708.571429  13762.857143  13771.428571  13762.857143
# std     2397.264723   2374.821532   2396.515327   2401.907505   2374.724221
# min    10200.000000  10200.000000  10200.000000  10200.000000  10200.000000
# 25%    12900.000000  12825.000000  12875.000000  12825.000000  12725.000000
# 50%    13200.000000  13200.000000  13250.000000  13250.000000  13200.000000
# 75%    13875.000000  13775.000000  13925.000000  14025.000000  13900.000000
# max    24850.000000  24850.000000  25000.000000  25000.000000  24900.000000
#
#             10/2022
# count     35.000000
# mean   13818.571429
# std     2372.144900
# min    10200.000000
# 25%    12800.000000
# 50%    13200.000000
# 75%    14050.000000
# max    24900.000000
#
# [8 rows x 32 columns]

# %%
def graphic_line_cmdty(psr, cmdty):
    link = '.\daerah\harga-pasar-'+psr+'-daerah.xls'
    df_hpmkb = pd.read_excel(link)
    
    prov = df_hpmkb[df_hpmkb['Komoditas(Rp)'] == cmdty]['Harga']
    period = df_hpmkb[df_hpmkb['Komoditas(Rp)'] == cmdty]['Periode']
    
    plt.figure(figsize=(40, 10))
    plt.plot(period,prov, color='grey', linewidth = 3, marker='o', markerfacecolor='grey', markersize=9)
    plt.grid(color='darkgray', linestyle=':', linewidth=0.5)
    plt.xlabel('Periode (Bulan)')
    plt.ylabel('Harga (Rp)')
    plt.savefig('.\output1\output-'+psr+'-'+cmdty+'.jpg', dpi=300)

tabel1 ='.\daerah\harga-pasar-modern-daerah.xls'
tabel2 = '.\daerah\harga-pasar-tradisional-daerah.xls'

graphic_line_cmdty('tradisional', 'Beras')

'''['Beras', 'Daging Ayam', 'Daging Sapi', 'Telur Ayam',
       'Bawang Merah', 'Bawang Putih', 'Cabai Merah', 'Cabai Rawit',
       'Minyak Goreng', 'Gula Pasir']
       '''
# Out:
# "['Beras', 'Daging Ayam', 'Daging Sapi', 'Telur Ayam',\n       'Bawang Merah', 'Bawang Putih', 'Cabai Merah', 'Cabai Rawit',\n       'Minyak Goreng', 'Gula Pasir']\n       "

# %%
#KITA MULAI DARI SINI...!!!
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

pasar = ['tradisional','modern']
komdt = ['Beras', 'Daging Ayam', 'Daging Sapi', 'Telur Ayam',
       'Bawang Merah', 'Bawang Putih', 'Cabai Merah', 'Cabai Rawit',
       'Minyak Goreng', 'Gula Pasir']

link = '.\daerah\harga-pasar-modern-daerah.xls'

df_hpmkb = pd.read_excel(link)


prov = df_hpmkb[df_hpmkb['Komoditas(Rp)'] == 'Cabai Merah']['Harga']
period = df_hpmkb[df_hpmkb['Komoditas(Rp)'] == 'Cabai Merah']['Periode']

#df_hpmkb.groupby(['Periode'])[prov].plot()
plt.figure(figsize=(30, 5))
#plt.plot(period,prov)
#plt.title('Harga Bahan Pangan Cabai Merah Tahun 2020 - 2022\n(pasar modern)')
plt.plot(period,prov, color='grey', linewidth = 3,
         marker='o', markerfacecolor='grey', markersize=9)
plt.grid(color='darkgray', linestyle=':', linewidth=0.5)
plt.xlabel('Periode (Bulan)')
plt.ylabel('Harga (Rp)')
plt.savefig('output.jpg', dpi=300)

# %%
df_hpmkb['Komoditas(Rp)'].unique()
# Out:
# array(['Beras', 'Daging Ayam', 'Daging Sapi', 'Telur Ayam',
#        'Bawang Merah', 'Bawang Putih', 'Cabai Merah', 'Cabai Rawit',
#        'Minyak Goreng', 'Gula Pasir'], dtype=object)

# %%
#munitions_by_country.py
import pandas as pd
from bokeh.plotting import figure, output_file, show
from bokeh.models import ColumnDataSource
from bokeh.models.tools import HoverTool

from bokeh.palettes import Spectral5
from bokeh.transform import factor_cmap
output_file('munitions_by_country.html')

link = '.\daerah\harga-pasar-modern-daerah.xls'

df_hpmkb = pd.read_excel(link)
df_hpmkb.head()

prov = df_hpmkb[df_hpmkb['Komoditas(Rp)'] == 'Cabai Merah']['Harga']
period = df_hpmkb[df_hpmkb['Komoditas(Rp)'] == 'Cabai Merah']['Periode']
 
# plotting the line graph
graph.line(prov, period)
 
# displaying the model
show(graph)

# %% [markdown]
# batas 0
# _________________
# #satu

# %%
# KERJAKAN SEKSI YANG INI!!
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

pasar = ['tradisional','modern']
komdt = ['Beras', 'Daging Ayam', 'Daging Sapi', 'Telur Ayam',
       'Bawang Merah', 'Bawang Putih', 'Cabai Merah', 'Cabai Rawit',
       'Minyak Goreng', 'Gula Pasir']

link = '.\daerah\harga-pasar-modern-daerah.xls'

df_hpmkb = pd.read_excel(link)


prov = df_hpmkb[df_hpmkb['Komoditas(Rp)'] == 'Cabai Merah']['Harga']
period = df_hpmkb[df_hpmkb['Komoditas(Rp)'] == 'Cabai Merah']['Periode']

#df_hpmkb.groupby(['Periode'])[prov].plot()
plt.figure(figsize=(30, 5))
#plt.plot(period,prov)
#plt.title('Harga Bahan Pangan Cabai Merah Tahun 2020 - 2022\n(pasar modern)')
plt.plot(period,prov, color='grey', linewidth = 3,
         marker='o', markerfacecolor='grey', markersize=9)
plt.grid(color='darkgray', linestyle=':', linewidth=0.5)
plt.xlabel('Periode (Bulan)')
plt.ylabel('Harga (Rp)')
plt.savefig('output.jpg', dpi=300)

# %%
plt.figure(figsize=(20, 8))
df_hk.group_by(['Provinsi'])['01/2022'].plot()
plt.title('Harga Pangan 2020 (pasar tradisional)')
plt.xlabel('Periode')
plt.ylabel('Harga (Rp)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\DQLAB_TETRIS_BATCH3_DATA_ANALYST\pangan\running-test.ipynb Cell 9 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/DQLAB_TETRIS_BATCH3_DATA_ANALYST/pangan/running-test.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(20, 8))
# ----> <a href='vscode-notebook-cell:/d%3A/DQLAB_TETRIS_BATCH3_DATA_ANALYST/pangan/running-test.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> df_hk.group_by(['Provinsi'])['01/2022'].plot()
#       <a href='vscode-notebook-cell:/d%3A/DQLAB_TETRIS_BATCH3_DATA_ANALYST/pangan/running-test.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> plt.title('Harga Pangan 2020 (pasar tradisional)')
#       <a href='vscode-notebook-cell:/d%3A/DQLAB_TETRIS_BATCH3_DATA_ANALYST/pangan/running-test.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> plt.xlabel('Periode')
#
# File c:\Users\User\anaconda3\envs\meet_5\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'group_by'

# %% [markdown]
# abtas 2
# _______________________________
#
# yang atas nanti dulu
#
# sekarang fokus ke csv filenya

# %%
import pandas as pd
df = pd.read_excel(".\daerah\harga-pasar-modern-daerah.xls")
df
dc = df.copy()
indek = dc.drop(['No.', '11/2022'], axis=1)
melet = indek.melt('Komoditas(Rp)', var_name='Periode(Bln)', value_name='Harga(Rp)')
melet2 = melet[melet['Komoditas(Rp)']== 'Beras']

# %%
melet2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 0 to 330
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Komoditas(Rp)  34 non-null     object
#  1   Periode(Bln)   34 non-null     object
#  2   Harga(Rp)      34 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.1+ KB

# %%
melet2['Periode(Bln)']= pd.to_datetime(melet2['Periode(Bln)'])

# %% [markdown]
# ## selanjutnya 22

# %%
import pandas as pd
df = pd.read_excel(".\daerah\harga-pasar-modern-daerah.xls")
df
dc = df.copy()
indek = dc.drop(['No.', '11/2022'], axis=1)
melet = indek.melt('Komoditas(Rp)', var_name='Periode(Bln)', value_name='Harga(Rp)')
melet
# Out:
#      Komoditas(Rp) Periode(Bln)  Harga(Rp)
# 0            Beras      01/2020      14400
# 1      Daging Ayam      01/2020      38050
# 2      Daging Sapi      01/2020     148450
# 3       Telur Ayam      01/2020      28150
# 4     Bawang Merah      01/2020      45250
# ..             ...          ...        ...
# 335   Bawang Putih      10/2022      36150
# 336    Cabai Merah      10/2022      92050
# 337    Cabai Rawit      10/2022      87200
# 338  Minyak Goreng      10/2022      23200
# 339     Gula Pasir      10/2022      14300
#
# [340 rows x 3 columns]

# %%
maks = melet[melet['Komoditas(Rp)'] == 'Beras']['Harga(Rp)'].min()
maks
# Out:
# 13250

# %%
melet['Periode(Bln)'].where(melet['Harga(Rp)'] == maks)[0]
# Out:
# '01/2020'

# %%
melet.groupby('Komoditas(Rp)').max()
# Out:
#               Periode(Bln)  Harga(Rp)
# Komoditas(Rp)
# Bawang Merah       12/2021      71200
# Bawang Putih       12/2021      58250
# Beras              12/2021      14400
# Cabai Merah        12/2021      99300
# Cabai Rawit        12/2021     107900
# Daging Ayam        12/2021      44200
# Daging Sapi        12/2021     168950
# Gula Pasir         12/2021      14950
# Minyak Goreng      12/2021      25900
# Telur Ayam         12/2021      32600

# %% [markdown]
# ### selanjutnya 33

# %%
import pandas as pd
lpi = pd.read_excel('.\modern\harga-pasar-modern-komoditas-beras.xls')
lpi2 = lpi.replace('-', 0)
lpi21 = lpi2.drop(['No.', '11/2022'], axis=1)
meti = lpi21.melt('Provinsi', var_name='Periode(Bln)', value_name='Harga(Rp)')
meti
# Out:
#             Provinsi Periode(Bln)  Harga(Rp)
# 0     SEMUA PROVINSI      01/2020      14400
# 1               ACEH      01/2020      12750
# 2     SUMATERA UTARA      01/2020      12600
# 3     SUMATERA BARAT      01/2020      15400
# 4               RIAU      01/2020      12950
# ...              ...          ...        ...
# 1185  SULAWESI BARAT      10/2022      10200
# 1186          MALUKU      10/2022      13150
# 1187    MALUKU UTARA      10/2022      13350
# 1188           PAPUA      10/2022      13500
# 1189     PAPUA BARAT      10/2022      13300
#
# [1190 rows x 3 columns]

# %%
mt = meti.groupby('Provinsi')['Harga(Rp)'].max()
mt
# Out:
# Provinsi
# ACEH                         12750
# BALI                         12600
# BANTEN                       17550
# BENGKULU                     20150
# DI YOGYAKARTA                15950
# DKI JAKARTA                  17900
# GORONTALO                    17200
# JAMBI                        12150
# JAWA BARAT                   14400
# JAWA TENGAH                  14250
# JAWA TIMUR                   12150
# KALIMANTAN BARAT             13300
# KALIMANTAN SELATAN           14250
# KALIMANTAN TENGAH            14050
# KALIMANTAN TIMUR             13250
# KALIMANTAN UTARA             13350
# KEPULAUAN BANGKA BELITUNG    13200
# KEPULAUAN RIAU               14550
# LAMPUNG                      29850
# MALUKU                       13250
# MALUKU UTARA                 18950
# NUSA TENGGARA BARAT          15000
# NUSA TENGGARA TIMUR          15950
# PAPUA                        13500
# PAPUA BARAT                  13450
# RIAU                         13300
# SEMUA PROVINSI               14400
# SULAWESI BARAT               10900
# SULAWESI SELATAN             16250
# SULAWESI TENGAH              13100
# SULAWESI TENGGARA            18750
# SULAWESI UTARA               12800
# SUMATERA BARAT               16100
# SUMATERA SELATAN             13100
# SUMATERA UTARA               13350
# Name: Harga(Rp), dtype: int64

# %%
mt['Harga(Rp)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\anaconda3\envs\meet_5\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File c:\Users\User\anaconda3\envs\meet_5\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\User\anaconda3\envs\meet_5\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Harga(Rp)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\User\projekpangan\running-test.ipynb Cell 25 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/projekpangan/running-test.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> mt['Harga(Rp)']
#
# File c:\Users\User\anaconda3\envs\meet_5\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\Users\User\anaconda3\envs\meet_5\lib\site-packages\pandas\core\series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File c:\Users\User\anaconda3\envs\meet_5\lib\site-packages\pandas\core\indexes\base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'Harga(Rp)'
